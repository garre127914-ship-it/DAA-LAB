# %% [markdown]
# <a href="https://colab.research.google.com/github/garre127914-ship-it/DAA-LAB/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0/1 Knapsack Problem using Dynamic Programming

# User input
n = int(input("Enter the number of items: "))

weights = []
values = []

print("Enter the weights of items:")
for i in range(n):
    weights.append(int(input()))

print("Enter the values of items:")
for i in range(n):
    values.append(int(input()))

capacity = int(input("Enter the knapsack capacity: "))

# DP table
dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

# Dynamic Programming
for i in range(1, n + 1):
    for w in range(1, capacity + 1):

        if weights[i - 1] <= w:
            dp[i][w] = max(
                values[i - 1] + dp[i - 1][w - weights[i - 1]],
                dp[i - 1][w]
            )
        else:
            dp[i][w] = dp[i - 1][w]

# Display result
print("\nMaximum value that can be obtained:")
print(dp[n][capacity])
# Out:
# Enter the number of items: 3
# Enter the weights of items:
# 2
# 3
# 4
# Enter the values of items:
# 4
# 4
# 5
# Enter the knapsack capacity: 7
#
# Maximum value that can be obtained:
# 9
