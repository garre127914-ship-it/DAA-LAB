# %% [markdown]
# <a href="https://colab.research.google.com/github/garre127914-ship-it/DAA-LAB/blob/main/practical%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# Iterative Factorial Function
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# User Input
n = int(input("Enter a non-negative integer: "))

if n < 0:
    print("Invalid input! Please enter a non-negative integer.")
else:
    # Start timer
    start_time = time.perf_counter_ns()

    # Calculate factorial
    result = factorial_iterative(n)

    # Stop timer
    end_time = time.perf_counter_ns()

    # Calculate execution time
    execution_time = end_time - start_time

    # Display result
    print(f"\n--- Iterative Factorial for {n}! ---")
    print("Factorial Result :", result)
    print("Execution Time   :", execution_time, "ns")

    # Time and Space Complexity
    print("\nTime Complexity:")
    print("O(n)")

    print("Space Complexity:")
    print("O(1)")
# Out:
# Enter a non-negative integer: 7
#
# --- Iterative Factorial for 7! ---
# Factorial Result : 5040
# Execution Time   : 4230 ns
#
# Time Complexity:
# O(n)
# Space Complexity:
# O(1)
